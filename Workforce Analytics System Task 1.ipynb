# %%
import pandas as pd

# %%
df = pd.read_csv("hr_analytics.xls")

# %%
df.sample(10)
# Out:
#      Age  Gender Department  MonthlyIncome  TotalWorkingYears  YearsAtCompany  \
# 758   40    Male         HR          19241                  9               4
# 897   23  Female         HR           7276                 28              10
# 850   32  Female      Sales          13593                  6              18
# 570   58    Male         HR           7727                 28              16
# 676   23  Female        R&D           3234                 29               5
# 721   43  Female      Sales          15903                 24               3
# 985   42  Female        R&D           9426                 18               4
# 213   22  Female        R&D          10804                 12              14
# 218   30    Male         HR           3778                 22               9
# 278   56  Female         HR          15605                 32              14
#
#      JobSatisfaction  WorkLifeBalance OverTime Attrition
# 758                3                2       No        No
# 897                1                2       No       Yes
# 850                4                3      Yes        No
# 570                3                1       No        No
# 676                4                4      Yes        No
# 721                3                1      Yes        No
# 985                3                2      Yes        No
# 213                4                1      Yes        No
# 218                3                2      Yes        No
# 278                4                3       No        No

# %%
df.shape
# Out:
# (1000, 10)

# %%
df.dtypes
# Out:
# Age                   int64
# Gender               object
# Department           object
# MonthlyIncome         int64
# TotalWorkingYears     int64
# YearsAtCompany        int64
# JobSatisfaction       int64
# WorkLifeBalance       int64
# OverTime             object
# Attrition            object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Age                  0
# Gender               0
# Department           0
# MonthlyIncome        0
# TotalWorkingYears    0
# YearsAtCompany       0
# JobSatisfaction      0
# WorkLifeBalance      0
# OverTime             0
# Attrition            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
len(df)
# Out:
# 1000

# %%
df["Department"].nunique()
# Out:
# 3

# %%
df["Department"].unique()
# Out:
# array(['HR', 'R&D', 'Sales'], dtype=object)

# %%
df["Age"].mean()
# Out:
# np.float64(40.947)

# %%
df["Age"].min()
# Out:
# 22

# %%
df["Age"].max()
# Out:
# 59

# %%
df["Gender"].value_counts()
# Out:
# Gender
# Male      504
# Female    496
# Name: count, dtype: int64

# %%
df["Department"].value_counts()
# Out:
# Department
# HR       352
# Sales    343
# R&D      305
# Name: count, dtype: int64

# %%
(df["TotalWorkingYears"]>10).sum()
# Out:
# np.int64(720)

# %%
(df["YearsAtCompany"]>5).sum()
# Out:
# np.int64(752)

# %%
df.groupby("Department")["MonthlyIncome"].mean()
# Out:
# Department
# HR       11604.042614
# R&D      11461.272131
# Sales    11417.247813
# Name: MonthlyIncome, dtype: float64

# %%
df[df["Attrition"] == "Yes"].groupby("Department").size()
# Out:
# Department
# HR       70
# R&D      74
# Sales    59
# dtype: int64
